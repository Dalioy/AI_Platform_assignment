# %% [markdown]
# # ياسر علي محمد محمد 2305268

# %%
import tensorflow as tf
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()

# %%
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]

# %%
X_train, X_valid, X_test = X_train / 255., X_valid / 255., X_test / 255.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
tf.keras.utils.plot_model(model, "my_fashion_mnist_model.png", show_shapes=True)

# %%
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=tf.keras.optimizers.SGD(),
    metrics=["sparse_categorical_accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.7192 - sparse_categorical_accuracy: 0.7592 - val_loss: 0.5486 - val_sparse_categorical_accuracy: 0.7968
# Epoch 2/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.4867 - sparse_categorical_accuracy: 0.8309 - val_loss: 0.4589 - val_sparse_categorical_accuracy: 0.8382
# Epoch 3/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.4429 - sparse_categorical_accuracy: 0.8458 - val_loss: 0.4139 - val_sparse_categorical_accuracy: 0.8508
# Epoch 4/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.4144 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.3917 - val_sparse_categorical_accuracy: 0.8608
# Epoch 5/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3940 - sparse_categorical_accuracy: 0.8628 - val_loss: 0.3818 - val_sparse_categorical_accuracy: 0.8636
# Epoch 6/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3775 - sparse_categorical_accuracy: 0.8671 - val_loss: 0.3717 - val_sparse_categorical_accuracy: 0.8650
# Epoch 7/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3637 - sparse_categorical_accuracy: 0.8729 - val_loss: 0.3742 - val_sparse_categorical_accuracy: 0.8716
# Epoch 8/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3519 - sparse_categorical_accuracy: 0.8745 - val_loss: 0.3663 - val_sparse_categorical_accuracy: 0.8722
# Epoch 9/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3410 - sparse_categorical_accuracy: 0.8786 - val_loss: 0.3454 - val_sparse_categorical_accuracy: 0.8750
# Epoch 10/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3314 - sparse_categorical_accuracy: 0.8817 - val_loss: 0.3637 - val_sparse_categorical_accuracy: 0.8696
# Epoch 11/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3232 - sparse_categorical_accuracy: 0.8855 - val_loss: 0.3484 - val_sparse_categorical_accuracy: 0.8746
# Epoch 12/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3143 - sparse_categorical_accuracy: 0.8879 - val_loss: 0.3464 - val_sparse_categorical_accuracy: 0.8754
# Epoch 13/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.8893 - val_loss: 0.3395 - val_sparse_categorical_accuracy: 0.8786
# Epoch 14/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3008 - sparse_categorical_accuracy: 0.8927 - val_loss: 0.3411 - val_sparse_categorical_accuracy: 0.8760
# Epoch 15/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2950 - sparse_categorical_accuracy: 0.8948 - val_loss: 0.3258 - val_sparse_categorical_accuracy: 0.8784
# Epoch 16/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2882 - sparse_categorical_accuracy: 0.8966 - val_loss: 0.3402 - val_sparse_categorical_accuracy: 0.8760
# Epoch 17/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2823 - sparse_categorical_accuracy: 0.8990 - val_loss: 0.3288 - val_sparse_categorical_accuracy: 0.8812
# Epoch 18/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2776 - sparse_categorical_accuracy: 0.8997 - val_loss: 0.3317 - val_sparse_categorical_accuracy: 0.8824
# Epoch 19/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2718 - sparse_categorical_accuracy: 0.9036 - val_loss: 0.3317 - val_sparse_categorical_accuracy: 0.8732
# Epoch 20/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2669 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.3218 - val_sparse_categorical_accuracy: 0.8806
# Epoch 21/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2619 - sparse_categorical_accuracy: 0.9054 - val_loss: 0.3188 - val_sparse_categorical_accuracy: 0.8830
# Epoch 22/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2578 - sparse_categorical_accuracy: 0.9070 - val_loss: 0.3280 - val_sparse_categorical_accuracy: 0.8774
# Epoch 23/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2528 - sparse_categorical_accuracy: 0.9092 - val_loss: 0.3284 - val_sparse_categorical_accuracy: 0.8808
# Epoch 24/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.2484 - sparse_categorical_accuracy: 0.9117 - val_loss: 0.3404 - val_sparse_categorical_accuracy: 0.8790
# Epoch 25/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2453 - sparse_categorical_accuracy: 0.9124 - val_loss: 0.3409 - val_sparse_categorical_accuracy: 0.8764
# Epoch 26/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.2408 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.3091 - val_sparse_categorical_accuracy: 0.8898
# Epoch 27/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.2365 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.3174 - val_sparse_categorical_accuracy: 0.8892
# Epoch 28/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2332 - sparse_categorical_accuracy: 0.9169 - val_loss: 0.3113 - val_sparse_categorical_accuracy: 0.8898
# Epoch 29/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2288 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.3120 - val_sparse_categorical_accuracy: 0.8876
# Epoch 30/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2253 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.3251 - val_sparse_categorical_accuracy: 0.8866
